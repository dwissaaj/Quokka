# %%
import pandas as pd
from pyvis.network import Network
import matplotlib.pyplot as plt
import networkx as nx

# %%
df = pd.read_excel("smalldata.xlsx")
graph = nx.from_pandas_edgelist(df,source="vertex1",target="vertex2")
nodes = graph.nodes()
edges = graph.edges()

# %%
x = nx.draw(graph,with_labels= True)

# %%
opinionleader = nx.degree_centrality(graph)
opinionleader
# Out:
# {'LITTLE, ABNER,': 0.13333333333333333,
#  'PRINCESS ZANDA': 0.13333333333333333,
#  "BLACK PANTHER/T'CHAL": 0.13333333333333333,
#  "BLACK PANTHER/T'CHAL,": 0.13333333333333333,
#  'STEELE, SIMON/WOLFGA,': 0.3333333333333333,
#  'FORTUNE, DOMINIC': 0.3333333333333333,
#  'ERWIN, CLYTEMNESTRA': 0.26666666666666666,
#  'IRON MAN/TONY STARK ': 0.2,
#  'IRON MAN IV/JAMES R.': 0.13333333333333333,
#  'RAVEN, SABBATH II/EL': 0.06666666666666667,
#  'RAVEN, SABBATH II/EL,': 0.26666666666666666,
#  'IRON MAN IV/JAMES R.,': 0.2,
#  'IRON MAN/TONY STARK ,': 0.13333333333333333,
#  'ERWIN, CLYTEMNESTRA,': 0.06666666666666667,
#  'PRINCESS ZANDA,': 0.13333333333333333,
#  'LITTLE, ABNER': 0.13333333333333333}
